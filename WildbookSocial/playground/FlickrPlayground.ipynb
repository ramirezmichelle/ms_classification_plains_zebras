# %% [markdown]
# ## Setup

# %%
#to reflect changes made in modules
# %load_ext autoreload
# %autoreload 2

# %%
# !pip -q install --upgrade -r ../requirements.txt --user
print("Packages successfully installed and up-to-date.")

#if errors occur while installing some packages - manually intall via command line and restart kernel
# Out:
# Packages successfully installed and up-to-date.

# %% [markdown]
# ## Keys + Requirements

# %%
#connect to database here
DB_KEY =  "mongodb+srv://user:BCLobB4rLJucVXG2@wildbook-cmmya.mongodb.net/test?retryWrites=true&w=majority"

# %%
import os, sys
sys.path.append(os.path.join(sys.path[0], '../'))

#file imports
from wildbook_social import Flickr, Database

db = Database(DB_KEY, 'flickr_june_2019')
fr = Flickr(db)
nameOfDb = 'flickr_june_2019'

# %% [markdown]
# ## Collection Maintenance (uncomment if needed)

# %% [markdown]
# Can ignore this section unless you need to rename a collection

# %%
# old =  
# new = 

# db.renameCollection(oldCollection = old, newCollection = new)
# db.renameCollection(oldCollection = old+' wild', newCollection = new + ' wild')

# %% [markdown]
# # General Query Terms

# %% [markdown]
# #### Terms that consist of more general, common, everyday names for species

# %% [markdown]
# Parameters
# - query = query term to use with flickr api to get image results
# - saveTo = collection results are saved to
# - query_bbox = bounding box coordinates parameter for flickr api

# %%
# #use saveTo to specify collection name
# query = "whale"
# saveTo = 'humpback whale general'
# query_bbox = False
#---------------------------------------------------------------------------#

# no general query terms for whale shark, specific only (next cell)

#---------------------------------------------------------------------------#
##IBERIAN LYNX COLLECTIONS (GENERAL)

# query = 'lynx' 
# saveTo = 'iberian lynx general' 
# query_bbox = False

# query = 'lynx, lince' 
# saveTo = 'iberian lynx general multilingual'
# query_bbox = False

##not searching with bbox bc limits our results by a significant amount
#---------------------------------------------------------------------------#
# query = 'giraffe'
# saveTo = 'reticulated giraffe general'
# query_bbox = False

# query = 'giraffe'
# saveTo = 'reticulated giraffe general africa bbox'
# query_bbox = '-18.615646,-34.936608,50.993729,35.266926'

# query = 'giraffe OR twiga OR girafe' #added on english keyword
# saveTo = 'reticulated giraffe general multilingual'
# query_bbox = False

# query = 'giraffe OR twiga OR girafe' #added on english keyword
# saveTo = 'reticulated giraffe general multilingual africa bbox'
# query_bbox = '-18.615646,-34.936608,50.993729,35.266926'

#---------------------------------------------------------------------------#

# query = 'zebra'
# saveTo = 'grevy zebra general'
# query_bbox = False

# query ='zebra'
# saveTo = 'grevy zebra general africa bbox'
# query_bbox = '-18.615646,-34.936608,50.993729,35.266926'

#---------------------------------------------------------------------------#
# query = 'zebra'
# saveTo = 'plains zebra general'
# query_bbox = False

# query = 'zebra'
# saveTo = 'plains zebra general africa bbox'
# query_bbox = '-18.615646,-34.936608,50.993729,35.266926'

# %% [markdown]
# # Specific Query Terms

# %% [markdown]
# #### Terms that contain specific species name, as opposed to more general terms

# %%
# query = 'humpback whale'
# saveTo = 'humpback whale specific'
# query_bbox = False
#---------------------------------------------------------------------------

# query = 'whale shark'
# saveTo = 'whale shark specific'
# query_bbox = False

# query = 'whale shark'
# saveTo = 'whale shark specific bbox'
# query_bbox = '-179.8877648511,-35.0428819504,179.9956736908,30.0340921155'

query = 'whale shark OR requin baleine OR tiburon ballena OR butanding'
saveTo = 'whale shark specific multilingual'
query_bbox = False

# query = 'whale shark OR requin baleine OR tiburon ballena OR butanding'
# saveTo = 'whale shark specific multilingual bbox'
# query_bbox = '-179.8877648511,-35.0428819504,179.9956736908,30.0340921155'

#---------------------------------------------------------------------------
# query= 'iberian lynx'
# saveTo='iberian lynx specific'
# query_bbox = False

# query= 'iberian lynx, lince iberico'
# saveTo= 'iberian lynx specific multilingual'
# query_bbox = False
#---------------------------------------------------------------------------
# RETICULATED GIRAFFES- SPECIFIC TERMS

# query = "reticulated giraffe OR somali giraffe"
# saveTo = "reticulated giraffe specific"
# query_bbox = False

# query = "reticulated giraffe OR somali giraffe"
# saveTo = "reticulated giraffe specific africa bbox"
# query_bbox = '-18.615646,-34.936608,50.993729,35.266926'
#---------------------------------------------------------------------------
# query = "grevy's zebra"
# saveTo = 'grevy zebra specific'
# query_bbox = False

# query = "grevy's zebra"
# saveTo = 'grevy zebra specific africa bbox'
# query_bbox = '-18.615646,-34.936608,50.993729,35.266926'

#---------------------------------------------------------------------------
# query = 'plains zebra'
# saveTo = 'plains zebra specific'
# query_bbox = False

# query = 'plains zebra'
# saveTo = 'plains zebra specific africa bbox'
# query_bbox = '-18.615646,-34.936608,50.993729,35.266926'

# %%
#to double check what collections/terms you're working with
print(query)
print(query_bbox)
print(saveTo)
# Out:
# whale shark OR requin baleine OR tiburon ballena OR butanding
# False
# whale shark specific multilingual

# %% [markdown]
# # Manual Filtration

# %% [markdown]
# Below is the cell to perform the manual filtration. Steps:
#
# 1. Specify amount to filter through (can vary on how many you feel like filtering at the moment)
# 2. The image will display. You will then be prompted if the image is relevant:
#     - enter 'y' if the image contains the species
#     - enter 'n' if the image does NOT contain the species
#
# 3. If you marked the image as relevant, you will be prompted to mark the image as a wild encounter or captive encounter:
#     - enter 'y' if the image appears to be of the species in its wild habitat
#     - enter 'n' if the species is in some sort of captive enclosure (zoo, sanctuary, aquarium, etc)
#
# The 'amount' displayed at the top of each image is how many images you have left to filter through

# %%
#retrieve images from collection specified with saveTo to manually filter for wild encounters

amount =  10 # amount to filter through
db.doManualFiltration(saveTo, amount) 
db.convertToUTC(saveTo) #convert dateTaken strings of documents in database to datetime objects
# Out:
# Amount:  10
# https://live.staticflickr.com/65535/51115626286_280f13d5d4_b.jpg
# Title: Great Hammerhead Shark with Dive Gear at Whale Harbor Marina in Islamorada, Florida Keys
# Tags:
# (Lat, Long): (24.937472,-80.612412)
#
# Didnt do Filenotfound error........................
#
# Relevant (y/n):
#  n
# Response saved! Not relevant and Not wild.
#
# Amount:  9
# https://live.staticflickr.com/31337/51100981038_f7b1b27cfd_b.jpg
# Title: Shark Hunter  Gameslot
# Tags: shark hunter slots slotgame slotgamesonline gameonline 123betting 123bet 123เบท 123vip 123vip4
# (Lat, Long): (0,0)
#
# Didnt do Filenotfound error........................
#
# Relevant (y/n):
# Response saved! Not relevant and Not wild.
#
# Amount:  8
# https://live.staticflickr.com/65535/51099304201_1ff5b6d49d_b.jpg
# Title: เกมส์ยิงปลาออนไลน์ 🔫Shark Hunter 🐟🐠🐬
# Tags: sharkhunter เกมยิงปลา เกมยิงปลาออนไลน์ เกมยิงปลายิงปลา สล๊อต สล็อตออนไลน์ เกมสล็อต สล็อตแมชชีน slots slotgame slotgamesonline gameonline 123betting 123bet 123เบท 123vip 123vip4
# (Lat, Long): (0,0)
#
# Didnt do Filenotfound error........................
#
# Relevant (y/n):
# Response saved! Not relevant and Not wild.
#
# Amount:  7
# https://live.staticflickr.com/65535/51091433662_639b73b2ee_b.jpg
# Title: Hey Mammy, I am here!
# Tags: seal antarcticfurseal animals freeanimals wildlife nature southgeorgia msfram
# (Lat, Long): (0,0)
#
# Didnt do Filenotfound error........................
#
# Relevant (y/n):
# Response saved! Not relevant and Not wild.
#
# Amount:  6
# https://live.staticflickr.com/65535/51007112065_d38ab66864_b.jpg
# Title: The Wall
# Tags: keywest florida unitedstates nature southflorida beauty monroecounty usa floridakeys islandchain tropical paradise warm fun exciting ninetymilesfromcuba marina keywestbight keywestbightmarina paintthewall mural seawall wyland oceanicmural blue streetphotography art reef artist painting seafloor sand sharks mantaray turtle coral hammerheadshark birds surface pelican island orange sunsetsky fish building wall street lights sign shadow bluesky palmtree thewall sunlit palmtreeshadows 2520 641am robertwyland
# (Lat, Long): (24.561068,-81.801323)
#
# Didnt do Filenotfound error........................
#
# Relevant (y/n):
# Response saved! Not relevant and Not wild.
#
# Amount:  5
# https://live.staticflickr.com/65535/51074268891_1d3d3f6515_b.jpg
# Title: The Beach of Sparkles
# Tags:
# (Lat, Long): (0,0)
#
# Didnt do Filenotfound error........................
#
# Relevant (y/n):
# Response saved! Not relevant and Not wild.
#
# Amount:  4
# https://live.staticflickr.com/65535/51062967451_997fc4b86a_b.jpg
# Title: Whale Shark
# Tags: whalesharkmaldives scuba diving virtualphotographers
# (Lat, Long): (2.746045,72.888793)
#
# Didnt do Filenotfound error........................
#
# Relevant (y/n):
#  y
# Wild(y/n):
#  y
# Response saved! Relevant and Wild.
#
# Amount:  3
# https://live.staticflickr.com/65535/51063050727_e841ef9d0b_b.jpg
# Title: Whale Shark
# Tags: whalesharkmaldives scuba diving virtualphotographers
# (Lat, Long): (2.746045,72.888793)
#
# Didnt do Filenotfound error........................
#
# Relevant (y/n):
#  y
# Wild(y/n):
#  y
# Response saved! Relevant and Wild.
#
# Amount:  2
# https://live.staticflickr.com/65535/51063049727_c7b97291bc_b.jpg
# Title: Swimming with Whale Sharks
# Tags: scuba diving virtualphotographers whaleshark blueforcefleet maldives
# (Lat, Long): (2.746045,72.888793)
#
# Didnt do Filenotfound error........................
#
# Relevant (y/n):
#  y
# Wild(y/n):
#  y
# Response saved! Relevant and Wild.
#
# Amount:  1
# https://live.staticflickr.com/65535/51062963846_ef5a3b8b5b_b.jpg
# Title: Whale Shark
# Tags: whalesharkmaldives scuba diving virtualphotographers
# (Lat, Long): (2.746045,72.888793)
#
# Didnt do Filenotfound error........................
#
# Relevant (y/n):
#  y
# Wild(y/n):
#  y
# Response saved! Relevant and Wild.
#
# No more items to proceed.

# %%
#update/create a collection consisting of wild documents only 
db.relevantDocuments(saveTo, nameOfDb)

# %% [markdown]
# # Closes Database Connection

# %%
db.close()
